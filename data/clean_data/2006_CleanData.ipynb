# %%
####Columns need to be renamed or dropped depending on how we decide to use the information.


import os
import csv
import pandas as pd

# %%
datafile = ( "../raw_data/retaildata_2006.csv")
two_thousand_six = pd.read_csv(datafile)

# %%
df=pd.DataFrame(two_thousand_six)
df
# Out:
#        NAICS                                         Unnamed: 1  \
# 0       CODE                                  NAICS DESCRIPTION
# 1         --                                              Total
# 2         --                                              Total
# 3         --                                              Total
# 4         --                                              Total
# 5         11  Forestry, Fishing, Hunting, and Agriculture Su...
# 6         11  Forestry, Fishing, Hunting, and Agriculture Su...
# 7         11  Forestry, Fishing, Hunting, and Agriculture Su...
# 8         11  Forestry, Fishing, Hunting, and Agriculture Su...
# 9        113                               Forestry and Logging
# 10       113                               Forestry and Logging
# 11       113                               Forestry and Logging
# 12       113                               Forestry and Logging
# 13      1131                            Timber Tract Operations
# ...

# %%
df2006 = df.rename(columns=df.iloc[0]).drop(df.index[0])
df2006
# Out:
#         CODE                                  NAICS DESCRIPTION  \
# 1         --                                              Total
# 2         --                                              Total
# 3         --                                              Total
# 4         --                                              Total
# 5         11  Forestry, Fishing, Hunting, and Agriculture Su...
# 6         11  Forestry, Fishing, Hunting, and Agriculture Su...
# 7         11  Forestry, Fishing, Hunting, and Agriculture Su...
# 8         11  Forestry, Fishing, Hunting, and Agriculture Su...
# 9        113                               Forestry and Logging
# 10       113                               Forestry and Logging
# 11       113                               Forestry and Logging
# 12       113                               Forestry and Logging
# 13      1131                            Timber Tract Operations
# 14      1131                            Timber Tract Operations
# ...

# %%
df6=df6.loc[df6['CODE'].isin(["442", "443","4451","448"])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-89be5c622f57> in <module>
# ----> 1 df6=df6.loc[df6['CODE'].isin(["442", "443","4451","448"])]
#
# NameError: name 'df6' is not defined

# %%
df6

# %%
t=df6.loc[(df6['DATA TYPE'] == "Establishments")|(df6['DATA TYPE'] == "Employment") & (df5['CODE'].isin(["442","443","4451","448"]))]
t

# %%
newdf2006 = t[t.columns[:2]]
newdf2006

# %%
 #makes Data Type column into seperate columns
testing = t.pivot(index="CODE",columns='DATA TYPE', values='TOTAL')
testing

# %%
mergedf=pd.merge(newdf2006, testing, how='left', on='CODE')
final=mergedf.drop_duplicates(subset=['CODE'])
#mergedf.rename(columns={'NAICS CODE': "CODE", 'Employment': 'Employment_2002','Establishments':'Establishments_2002'})

# %%
final

# %%
final2006=final.rename(columns={'Employment': 'Employment_2006','Establishments':'Establishments_2006'})
final2006

# %%
#save the final datatframe as a csvfile
final2006.to_csv("Output/2006_cleandata.csv",header=True,index=False)
