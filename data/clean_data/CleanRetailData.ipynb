# %%
import os
import csv
import pandas as pd

# %%
datafile = ( "../raw_data/retaildata_2000.csv")
data_zero = pd.read_csv(datafile)

# %%
df=pd.DataFrame(data_zero)
df
# Out:
#        NAICS                                         Unnamed: 1  \
# 0       CODE                                  NAICS DESCRIPTION
# 1         --                                              Total
# 2         --                                              Total
# 3         --                                              Total
# 4         --                                              Total
# 5         11          Agriculture, forestry, fishing, & hunting
# 6         11          Agriculture, forestry, fishing, & hunting
# 7         11          Agriculture, forestry, fishing, & hunting
# 8         11          Agriculture, forestry, fishing, & hunting
# 9        113                               Forestry and logging
# 10       113                               Forestry and logging
# 11       113                               Forestry and logging
# 12       113                               Forestry and logging
# 13      1131                            Timber tract operations
# ...

# %%
df2000 = df.rename(columns=df.iloc[0]).drop(df.index[0])

# %%
df2000
# Out:
#         CODE                                  NAICS DESCRIPTION  \
# 1         --                                              Total
# 2         --                                              Total
# 3         --                                              Total
# 4         --                                              Total
# 5         11          Agriculture, forestry, fishing, & hunting
# 6         11          Agriculture, forestry, fishing, & hunting
# 7         11          Agriculture, forestry, fishing, & hunting
# 8         11          Agriculture, forestry, fishing, & hunting
# 9        113                               Forestry and logging
# 10       113                               Forestry and logging
# 11       113                               Forestry and logging
# 12       113                               Forestry and logging
# 13      1131                            Timber tract operations
# 14      1131                            Timber tract operations
# ...

# %%
df2000=df2000.loc[df2000['CODE'].isin(["--","442", "443","4451","448"])]

# %%
df2000
# Out:
#       CODE                       NAICS DESCRIPTION                DATA TYPE  \
# 1       --                                   Total                    Firms
# 2       --                                   Total           Establishments
# 3       --                                   Total               Employment
# 4       --                                   Total  Annual Payroll ($1,000)
# 4489   442     Furniture & home furnishings stores                    Firms
# 4490   442     Furniture & home furnishings stores           Establishments
# 4491   442     Furniture & home furnishings stores               Employment
# 4492   442     Furniture & home furnishings stores  Annual Payroll ($1,000)
# 4529   443          Electronics & appliance stores                    Firms
# 4530   443          Electronics & appliance stores           Establishments
# 4531   443          Electronics & appliance stores               Employment
# ...

# %%
len(df2000)

# %%
#df2000.set_index(['CODE'])
t=df2000.loc[(df2000['DATA TYPE'] == "Establishments") & df2000['CODE'].isin(["--","442","443","4451","448"])]
t
# Out:
#       CODE                       NAICS DESCRIPTION       DATA TYPE      TOTAL  \
# 2       --                                   Total  Establishments  7,070,048
# 4490   442     Furniture & home furnishings stores  Establishments     64,842
# 4530   443          Electronics & appliance stores  Establishments     45,592
# 4630  4451                          Grocery stores  Establishments     98,275
# 4774   448  Clothing & clothing accessories stores  Establishments    150,946
#
#             0        1-4        5-9    10-19        <20    20-99  100-499  \
# 2     730,027  2,675,974  1,035,370  652,461  5,093,832  674,106  312,112
# 4490    4,820     22,160     11,436    7,164     45,580    6,407    3,099
# 4530    4,044     15,608      7,123    4,020     30,795    2,933    1,096
# 4630    9,246     31,243     12,195    8,322     61,006    9,122    3,982
# 4774    7,447     36,578     15,041    7,471     66,537    6,739    5,738
#
#            <500     500+
# 2     6,080,050  989,998
# ...
